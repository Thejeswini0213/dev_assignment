# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/winequalityN.csv')
DF=df.head()
DF

# %%
DF.describe()

# %%
DF.nunique()

# %%
DF.isnull().sum()

# %%
DF.info()

# %%
DF.shape

# %%
DF['sulphates'].mean()

# %%
x=DF.alcohol
y=DF.quality

# %%
plt.plot(x,y)
plt.title('WINE QUALITY')

# %%
plt.bar(x,y,color='deeppink')
plt.title('WINE QUALITY')

# %%
plt.scatter(x,y,color="green")
plt.title('WINE QUALITY')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
plt.hist(x,color='red')
plt.title('WINE QUALITY')
# Out:
# Text(0.5, 1.0, 'WINE QUALITY')

# %%
DF.plot.hist(stacked=True,bins=40)
plt.title('WINE QUALITY')
# Out:
# Text(0.5, 1.0, 'WINE QUALITY')

# %%
plt.title("LINE GRAPH")
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x,y,color="blue")
plt.title('WINE QUALITY',color='deeppink')
# Out:
# Text(0.5, 1.0, 'WINE QUALITY')

# %%
plt.stackplot(x,y,color="cyan")
plt.xlabel('x')
plt.ylabel('y')
plt.title('WINE QUALITY',color='red')
# Out:
# Text(0.5, 1.0, 'WINE QUALITY')

# %%
plt.pie(x)
plt.title("x")
plt.legend()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
plt.boxplot(x)
plt.title('WINE QUALITY',color='orange')
# Out:
# Text(0.5, 1.0, 'WINE QUALITY')

# %%
plt.step(x,y,color="darkviolet")
plt.title('WINE QUALITY',color='cyan')
# Out:
# Text(0.5, 1.0, 'WINE QUALITY')

# %%
plt.stem(x,y)
plt.title('WINE QUALITY')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.
# Text(0.5, 1.0, 'WINE QUALITY')

# %%
plt.polar(y)
plt.title('WINE QUALITY')
# Out:
# Text(0.5, 1.05, 'WINE QUALITY')

# %%
sns.heatmap(DF.corr())
plt.title('WINE QUALITY')
# Out:
# Text(0.5, 1.0, 'WINE QUALITY')
